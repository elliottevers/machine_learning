# %% [markdown]
# # Chapter 7

# %% [markdown]
# Problems 1, 2, 3, 5, 6, 9, 10, 11

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ![alttext](img/p1a.png)
# ![alttext](img/p1b.png)

# %% [markdown]
# ## (a)

# %% [markdown]
# **define generalized polynomial over first subdomain**
#
# Let
# $$
# f _ { 1 } ( x ) = a _ { 1 } + b _ { 1 } x + c _ { 1 } x ^ { 2 } + d _ { 1 } x ^ { 3 }
# $$.
#
# **make it equivalent to polynomial under consideration over first subdomain**
#
# We can set $f(x) = f_2 (x)$ for $x \leq \xi$ by equating their coefficients
# $$a _ { 1 } = \beta _ { 0 }, b _ { 1 } = \beta _ { 1 }, c _ { 1 } = \beta _ { 3 }, d _ { 1 } = \beta _ { 4 }$$.
#
# **polynomial under consideration is a generalized polynomial**
#
# But $f_1$ is a generalized polynomial for $x \leq \xi$, so $f$ is as well.

# %% [markdown]
# ## (b)

# %% [markdown]
# **restate our polynomial under consideration**
#
# Recall our function
# $$
# f ( x ) = \beta _ { 0 } + \beta _ { 1 } x + \beta _ { 2 } x ^ { 2 } + \beta _ { 3 } x ^ { 3 } + \beta _ { 4 } ( x - \xi ) ^ { 3 }
# $$.
#
# **simplify**
#
# We can rearrange to produce
# $$
# f(x) = \left( \beta _ { 0 } - \beta _ { 4 } \xi ^ { 3 } \right) + \left( \beta _ { 1 } + 3 \beta _ { 4 } \xi ^ { 2 } \right) x + \beta _ { 3 } x ^ { 3 } + \beta _ { 4 } \left( x ^ { 3 } - 3 \xi x ^ { 2 } + 3 \xi ^ { 2 } x - \xi ^ { 3 } \right)
# $$.
#
# **define generalized polynomial over second subdomain**
#
# Let
# $$
# f _ { 2 } ( x ) = a _ { 2 } + b _ { 2 } x + c _ { 2 } x ^ { 2 } + d _ { 2 } x ^ { 3 }
# $$ be a generalized polynomial.
#
#
# **make polynomials equivalent**
#
# We can set $f(x) = f_2 (x)$ by equating their coefficients
# $$
# a _ { 2 } = \beta _ { 0 } - \beta _ { 4 } \xi ^ { 3 }, \\
# b _ { 2 } = \beta _ { 1 } + 3 \beta _ { 4 } \xi ^ { 2 }, \\
# c _ { 2 } = \beta _ { 2 } - 3 \beta _ { 4 } \xi, \\
# d _ { 2 } = \beta _ { 3 } + \beta _ { 4 }
# $$.
#
#
# **polynomial under consideration is a polynomial over second subdomain**
#
# But $f_2$ is a generalized polynomial for $x > \xi$, so $f$ is as well.

# %% [markdown]
# **in summary and as a segue, define f as piecewise function**
#
# In summary we've showed the $f$ can be characterized as $$
# f(x) = \begin{array}{ll}
#       f_1(x) & x\leq \xi \\
#       f_2(x) & x > \xi\\
# \end{array}
# $$.

# %% [markdown]
# ## (c)

# %% [markdown]
# **consider possibly discontinuous points of f**
#
# Polynomials are continuous everywhere, so the only place we have to check is the knot.
#
# **show right hand limit is equivalent to left hand limit**
#
# Since $f_1$ is a polynomial, and again polynomials are continuous everywhere, the left hand limit of $f(\xi)$ is $f_1(\xi)$.  Similarly, the right hand limit of $f(\xi)$ is $f_2(\xi)$.  To prove continuity, we must show $f _ { 1 } ( \xi ) = f _ { 2 } ( \xi )$.
#
# By definition,
# $$
# f _ { 1 } ( \xi ) = \beta _ { 0 } + \beta _ { 1 } \xi + \beta _ { 2 } \xi ^ { 2 } + \beta _ { 3 } \xi ^ { 3 }
# $$
#
# Simplifying, we get
# $$
# f _ { 2 } ( \xi ) = \\
# \left( \beta _ { 0 } - \beta _ { 4 } \xi ^ { 3 } \right) + \left( \beta _ { 1 } + 3 \beta _ { 4 } \xi ^ { 2 } \right) \xi + \left( \beta _ { 2 } - 3 \beta _ { 4 } \xi \right) \xi ^ { 2 } + \left( \beta _ { 3 } + \beta _ { 4 } \right) \xi ^ { 3 } = \\
# \beta _ { 0 } + \beta _ { 1 } \xi + \beta _ { 2 } \xi ^ { 2 } + \beta _ { 3 } \xi ^ { 3 }
# $$
#
# **f(x) is continuous at $\xi$**
#
# Thus, $f$ is continuous at its knot.

# %% [markdown]
# ## (d - e)

# %% [markdown]
# Once we take the necessary derivatives, the arguments are identical to above.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ![alttext](img/p2.png)

# %% [markdown]
# Note that it's sufficient to minimize the $\lambda \int \left[ g ^ { ( m ) } ( x ) \right] ^ { 2 } d x$ term.

# %% [markdown]
# ## (a)

# %% [markdown]
# Consider a polynomial basis function $g$.  If we square it, it will become symmetric, since multiplying any number by 2 produces an even number.  If we integrate it, it will become anti-symmetric, since adding 1 to an even number will always produce an odd number.
#
# Now, we have to find a function on which the difference between any two points is minimized.  This is obviously a *constant* function.  What function $g$ will produce a constant function when squared and integrated?  Only **g = 0**.

# %% [markdown]
# ## (b - d)

# %% [markdown]
# Using the same argument as above, we arrive at
#
# - g is constant
# - g is linear
# - g is quadratic
#
# , respectively.

# %% [markdown]
# ## (e)

# %% [markdown]
# When $\lambda = 0$ the term with the integral will be zero and it only matters how closely $g$ fits our data.  Thus, **the g that most closely approximates our data** will minimize the function.

# %% [markdown]
# ## Problem 3

# %% [markdown]
# ![alttext](img/p3.png)

# %% [markdown]
# ![alttext](img/p3a.png)

# %% [markdown]
# ## Problem 5

# %% [markdown]
# ![alttext](img/p5.png)

# %% [markdown]
# ## (a)

# %% [markdown]
# How will second term ("regularization term") select $g$ as to keep the function to a minimum?
#
# **two separate sequences of functions converge to two different models of differing complexity**
#
# It will attempt to find, for both functions, a sequence of $g$s that converge to the zero function.
#
# **quantify flexibility of model**
#
# The function $\hat { g } _ { 1 }$ will select a quadratic polynomial and $\hat { g } _ { 2 }$ will select a cubic polynomial.
#
# **the general behavior of MSE as a function of model flexibility is well known**
#
# We know that cubic polynomials are more flexible, and moore flexible models have lower training error, so $\hat { g } _ { 2 }$ will have smaller training error.

# %% [markdown]
# ## (b)

# %% [markdown]
# We could potentially use the $C_p$ statistic to derive an estimate for test error from the training error.  Since we expect the *variance* of the cubic model to be higher than that of the *quadratic* model, and we already know the former's flexibility is higher, we would expect $\hat { \boldsymbol { g } } _ { 1 }$ to have smaller test RSS.

# %% [markdown]
# ## (c)

# %% [markdown]
# The regularization term will be zero, and the optimization problem will produce exactly the same sequence of models.  Thus, the two RSSs will be equivalent.

# %% [markdown]
# ## Problem 6

# %% [markdown]
# ![alttext](img/p6.png)

# %% [markdown]
# ## (a)

# %%
library(ISLR)
library(boot)

# %%
set.seed(9002)

data <- Wage

deltas = rep(NA, 10)

for (i in 1:10) {
    
  model = glm(
      wage~poly(age, i),
      data=Wage
  )
    
  deltas[i] = cv.glm(
      data,
      model,
      K=10
  )$delta[2]
    
}

plot(
    1:10,
    deltas,
    xlab="D",
    ylab="CV error",
    type="l"
)

# which hyperparameter (degree) produces lowest cross validation error

delta_min = min(deltas)

which.min(all.deltas)
# Out:
# [1] 5
# plot without title

# %% [markdown]
# ## model with degree 5 has lowest cross validation error, but we should probably choose the roughly similar but less complex model with degree 2

# %%
install.packages('gsubfn')
# Out:
# Installing package into ‘/usr/local/lib/R/3.5/site-library’
# (as ‘lib’ is unspecified)
# also installing the dependency ‘proto’

# %%
install.packages('purrr')
# Out:
# Installing package into ‘/usr/local/lib/R/3.5/site-library’
# (as ‘lib’ is unspecified)

# %%
library(gsubfn)
# Out:
# Loading required package: proto
# Could not load tcltk.  Will use slower R code instead.

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library(purrr)

# %%
fit_polynomial_models <- function(integer){
    return (
        1:integer %>% map(
            function(integer2) lm(
                wage~poly(
                    age,
                    integer2
                ),
                data=data
            )
        )
   )
}

# %%
# determine which model has most statistical significance

lift(anova)(fit_polynomial_models(10))
# Out:
#    Res.Df RSS     Df Sum of Sq    F            Pr(>F)
# 1  2998   5022216 NA           NA           NA           NA
# 2  2997   4793430  1 2.287860e+05 1.437638e+02 2.187330e-32
# 3  2996   4777674  1 1.575569e+04 9.900512e+00 1.668583e-03
# 4  2995   4771604  1 6.070152e+03 3.814342e+00 5.090874e-02
# 5  2994   4770322  1 1.282563e+03 8.059328e-01 3.693978e-01
# 6  2993   4766389  1 3.932258e+03 2.470939e+00 1.160744e-01
# 7  2992   4763834  1 2.555281e+03 1.605679e+00 2.051989e-01
# 8  2991   4763707  1 1.266690e+02 7.959584e-02 7.778654e-01
# 9  2990   4756703  1 7.004317e+03 4.401350e+00 3.599425e-02
# 10 2989   4756701  1 2.637537e+00 1.657367e-03 9.675292e-01

# %% [markdown]
# ## The polynomial model with degree 2 is most significant

# %%
# plot test data

plot(
    wage~age,
    data=data,
    col="darkgrey"
)


# limits of domain of fitted model

range_domain = range(
    data$age
)

# domain of fitted model

domain = seq(
    from=range_domain[1],
    to=range_domain[2]
)


# fit cubic polynomial model 

model = lm(
    wage~poly(
        age,
        3
    ),
    data=data
)

# generate approximation

predictions = predict(
    model,
    data.frame(
        age=domain
    )
)

# plot approximation

lines(
    domain,
    predictions,
    col="blue",
    lwd=2
)
# Out:
# plot without title

# %% [markdown]
# ## Problem 9

# %% [markdown]
# ![alttext](img/p9.png)

# %% [markdown]
# ## (a)

# %%
library(MASS)

# %%
set.seed(9001)

data <- Boston

model = lm(
    nox ~ poly(dis, 3),
    data = data
)

summary(model)

# range of domain
range_dis = range(dis)

# domain
domain = seq(
    from = range_dis[1],
    to = range_dis[2],
    by = 0.01
)

# generate approximations
predictions = predict(
    model,
    list(dis = domain)
)

# plot training data
plot(
    nox ~ dis,
    data = data,
    col = "darkgrey"
)

# plot approximations
lines(
    domain,
    predictions,
    col = "red"
)
# Out:
# Call:
# lm(formula = nox ~ poly(dis, 3), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.121130 -0.040619 -0.009738  0.023385  0.194904
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.554695   0.002759 201.021  < 2e-16 ***
# poly(dis, 3)1 -2.003096   0.062071 -32.271  < 2e-16 ***
# poly(dis, 3)2  0.856330   0.062071  13.796  < 2e-16 ***
# poly(dis, 3)3 -0.318049   0.062071  -5.124 4.27e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06207 on 502 degrees of freedom
# Multiple R-squared:  0.7148,	Adjusted R-squared:  0.7131
# F-statistic: 419.3 on 3 and 502 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# ## (b)

# %%
rss_vec = rep(NA, 10)

for (i in 1:10) {
    model = lm(
        nox ~ poly(dis, i),
        data = data
    )
    rss_vec[i] = sum(
        model$residuals^2
    )
}

rss_df <- data.frame(
    degree = 1:length(rss_vec),
    rsss = rss_vec
)

plot(
    rss_df
)
# Out:
# plot without title

# %% [markdown]
# ## (c)

# %%
# perform cross validation for each hyperparameter (degree)

cv_err = rep(NA, 10)

for (i in 1:10) {
    
  model = glm(
      nox ~ poly(dis, i),
      data=data
  )
    
  cv_err[i] = cv.glm(
      data,
      model,
      K=10
  )$delta[2]
    
}

# get minimum of cross validation errors

which.min(cv_err)

# plot to verify

plot(
    1:10,
    cv_err,
    xlab="Degree",
    ylab="CV error",
    type="l"
)
# Out:
# [1] 3
# plot without title

# %% [markdown]
# **The model using 3 degrees achieved the best results**

# %% [markdown]
# ## (d - f)

# %%
library(splines)

# fit model using splines
model = lm(
    nox ~ bs(
        dis
    ),
    data = data
)

# report fit
summary(model)

# generate approximations
predictions = predict(
    model,
    list(dis = domain)
)

# plot original data
plot(
    nox ~ dis,
    data = Boston,
    col = "darkgrey"
)

# plot approximation
lines(
    domain,
    predictions,
    col = "red"
)
# Out:
# Call:
# lm(formula = nox ~ bs(dis), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.121130 -0.040619 -0.009738  0.023385  0.194904
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.755153   0.008283  91.168  < 2e-16 ***
# bs(dis)1    -0.498271   0.032542 -15.312  < 2e-16 ***
# bs(dis)2    -0.233520   0.036994  -6.312 6.05e-10 ***
# bs(dis)3    -0.382680   0.045455  -8.419 4.00e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06207 on 502 degrees of freedom
# Multiple R-squared:  0.7148,	Adjusted R-squared:  0.7131
# F-statistic: 419.3 on 3 and 502 DF,  p-value: < 2.2e-16
# plot without title

# %%
list_df = rep(NA, 20)

cv_deltas = rep(NA, 20)

for (i in 1:length(list_df)) {
    
    model = glm(
        nox ~ bs(dis, df = i),
        data = data
    )
    
    cv_deltas[i] = cv.glm(
        data,
        model,
        K = 5
    )$delta[2]
}

# plot cross validation error for each degree of freedom

plot(
    1:length(list_df),
    cv_deltas,
    type = "l",
    xlab = "df",
    ylab = "CV error"
)
# Out:
# Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, df = i):
# “'df' was too small; have used 3”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = numeric(0), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`50%` = 3.1323), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`50%` = 3.1323), Boundary.knots = c(1.1296, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`50%` = 3.2628), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`50%` = 3.2628), Boundary.knots = c(1.137, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`33.33333%` = 2.4298, `66.66667%` = 4.4272:
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`33.33333%` = 2.4298, `66.66667%` = 4.4272:
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`25%` = 2.1007, `50%` = 3.2628, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`25%` = 2.1007, `50%` = 3.2628, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`20%` = 1.9512, `40%` = 2.5961, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`20%` = 1.9512, `40%` = 2.5961, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`20%` = 1.94848, `40%` = 2.65716, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`20%` = 1.94848, `40%` = 2.65716, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`16.66667%` = 1.82065, `33.33333%` = 2.3727, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`16.66667%` = 1.82065, `33.33333%` = 2.3727, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`16.66667%` = 1.8951, `33.33333%` = 2.4329, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`16.66667%` = 1.8951, `33.33333%` = 2.4329, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`14.28571%` = 1.7928, `28.57143%` = 2.2126, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`14.28571%` = 1.7928, `28.57143%` = 2.2126, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`14.28571%` = 1.77501428571429, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`14.28571%` = 1.77501428571429, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`12.5%` = 1.75385, `25%` = 2.0527, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`12.5%` = 1.75385, `25%` = 2.0527, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`12.5%` = 1.7504875, `25%` = 2.1027, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`12.5%` = 1.7504875, `25%` = 2.1027, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`11.11111%` = 1.75264444444444, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`11.11111%` = 1.75264444444444, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`11.11111%` = 1.72783333333333, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`11.11111%` = 1.72783333333333, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`10%` = 1.61229, `20%` = 1.94088, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`10%` = 1.61229, `20%` = 1.94088, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`9.090909%` = 1.58946363636364, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`9.090909%` = 1.58946363636364, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`9.090909%` = 1.61669090909091, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`9.090909%` = 1.61669090909091, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`8.333333%` = 1.6104, `16.66667%` = 1.86683333333333, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`8.333333%` = 1.6104, `16.66667%` = 1.86683333333333, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`8.333333%` = 1.5909, `16.66667%` = 1.8699, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`8.333333%` = 1.5909, `16.66667%` = 1.8699, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.692308%` = 1.5395, `15.38462%` = 1.80869230769231, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.692308%` = 1.5395, `15.38462%` = 1.80869230769231, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.692308%` = 1.6074, `15.38462%` = 1.8498, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.692308%` = 1.6074, `15.38462%` = 1.8498, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.142857%` = 1.5184, `14.28571%` = 1.7821, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.142857%` = 1.5184, `14.28571%` = 1.7821, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.142857%` = 1.53235, `14.28571%` = 1.81712857142857, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`7.142857%` = 1.53235, `14.28571%` = 1.81712857142857, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`6.666667%` = 1.57140666666667, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`6.666667%` = 1.57140666666667, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`6.666667%` = 1.51828, `13.33333%` = 1.76945333333333, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`6.666667%` = 1.51828, `13.33333%` = 1.76945333333333, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`6.25%` = 1.51855, `12.5%` = 1.7469625, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`6.25%` = 1.51855, `12.5%` = 1.7469625, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`5.882353%` = 1.51896470588235, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`5.882353%` = 1.51896470588235, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`5.555556%` = 1.51326666666667, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`5.555556%` = 1.51326666666667, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`5.555556%` = 1.48195555555556, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”Warning message in bs(dis, degree = 3L, knots = c(`5.555556%` = 1.48195555555556, :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# plot without title

# %% [markdown]
# ## Problem 10

# %% [markdown]
# ![alttext](img/p10.png)

# %% [markdown]
# ## (a - d)

# %%
library(ISLR)
library(leaps)

# %%
set.seed(9001)

data <- College

indices_train = sample(
    length(data$Outstate),
    length(data$Outstate)/2
)

indices_test <- -indices_train

data_train <- data[indices_train, ]

data_test <- data[indices_test, ]

# perform forward stepwise selection to produce models

model = regsubsets(
    Outstate ~ .,
    data = data_train,
    nvmax = 20,
    method = "forward"
)

summary = summary(model)

plot(
    summary$adjr2,
    xlab = "Num Predictors",
    ylab = "Adjusted R2", 
    type = "l"
)

# to choose "satisfactory" model, choose max of adjusted r2

points(
    x = which.max(summary$adjr2),
    y = max(summary$adjr2),
    col = "red"
)

r2_max = max(
    summary$adjr2
)

model_best_subset = regsubsets(
    Outstate ~ .,
    data = data_train,
    method = "forward"
)

coef(
    model_best_subset,
    id = 8
)
# Out:
#   (Intercept)    PrivateYes   F.Undergrad    Room.Board      Personal
# -3.548670e+03  2.112305e+03 -6.620658e-02  8.394109e-01 -4.122604e-01
#      Terminal   perc.alumni        Expend     Grad.Rate
#  4.346050e+01  4.063738e+01  2.952988e-01  3.584862e+01
# plot without title

# %% [markdown]
# ## (b)

# %%
install.packages("gam")
# Out:
# Installing package into ‘/usr/local/lib/R/3.5/site-library’
# (as ‘lib’ is unspecified)

# %%
library(gam)
# Out:
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loaded gam 1.16

# %%
gam.fit = gam(
    Outstate ~ Private +
        s(F.Undergrad, df = 2) +
        s(Room.Board, df = 2) + 
        s(Personal, df = 2) +
        s(Terminal, df = 2) +
        s(perc.alumni, df = 2) +
        s(Expend, df = 2) +
        s(Grad.Rate, df = 2),
    data = College.train
)

plot(
    gam.fit,
    se = T,
    col = "blue"
)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
